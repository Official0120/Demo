# %% [markdown]
# **1 -** Write a Python program to check if a number is positive, negative or zero.

# %%
num = int(input('Enter any Number :'))

if num > 0 :
  print(num,"is a positive Number...!")
elif num == 0 :
  print(" it's zero...!")
else :
  print(num,"is a negative Number...!")

# %% [markdown]
# **2 -** Write a Python program to get the Factorial number of given number.

# %%
num = int(input('Enter any Number :'))

factorial = 1

if num == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1,num + 1):
       factorial = factorial*i
   print("The factorial of",num,"is",factorial)

# %% [markdown]
#  **3 -** Write a Python program to get the Fibonacci series of given range.

# %%
num = int(input("How many number ? "))
n1, n2 = 0, 1
print("Fibonacci Series:", n1, n2, end=" ")
for i in range(2, num):
    n3 = n1 + n2
    n1 = n2
    n2 = n3
    print(n3, end=" ")
print( )

# %% [markdown]
#  **4 -**  Memory is managed in Python?

# %% [markdown]
# **Ans -**

# %% [markdown]
# **5 -** What is the purpose of continue statement in python?

# %% [markdown]
# **Ans -** The continue keyword is used to end the current iteration in the loops, and continues to the next iteration.

# %% [markdown]
# **6 -** Write python program that swap two number with temp variable and without temp variable.

# %%
# Program without using temp variable :
x = int(input("Enter First number : "))
y = int(input("Enter second number : ")) 
x, y = y, x
print ("swapped values : ")
print("First Number : ", x)
print("Second Number : ", y)

# %%
# Program with temp variable :
x = int(input("Enter First number : "))
y = int(input("Enter second number : "))
temp = x
x = y
y = temp
print ("swapped values : ")
print('First number: {}'.format(x))
print('Second number: {}'.format(y))

# %% [markdown]
# **7 -** Write a Python program to find whether a given number is even or odd, print out an appropriate message to the user.

# %%
x = int(input("Enter a Number :"))
if x % 2 == 0 :
  print("The Number you have entered is even.")
else :
  print("The Number you have entered is odd.")

# %% [markdown]
# **8 -** Write a Python program to test whether a passed letter is a vowel or not.

# %%
x = input("Enter a letter :")
y = ('a','A','e','E','i','I','o','O','u','U')

if x in y :
  print("The letter you've entered is a vovel.")
else :
  print("The letter you've entered is not a vovel.")

# %% [markdown]
# **9 -** Write a Python program to sum of three given integers.However, if two values are equal sum will be zero.

# %%
x = int(input("Enter 1st Number :"))
y = int(input("Enter 2nd Number :"))
z = int(input("Enter 3rd Number :"))

if x == y or x == z or y == z :
  print("the sum is = 0")
else :
  a = x + y + z
  print("Sum of all three numbers is :",a)

# %% [markdown]
# **10 -** Write a Python program that will return true if the two given integer values are equal or their sum or difference is 5.

# %%
x = int(input("Enter 1st Number :"))
y = int(input("Enter 2nd Number :"))

a = x + x
b = y + y
c = x - y == 5
d = y - x == 5

if x == y or a == b or c or d :
  print("True")
else :
  print("False")

# %% [markdown]
# **11 -** Write a python program to sum of the first n positive integers.

# %%
n = int(input("Enter an integers:"))
sum_n = (n * (n + 1)) / 2
print(sum_n)

# %% [markdown]
# **12 -** Write a Python program to calculate the length of a string.

# %%
s = input("Write a  String :")
len(s)

# %% [markdown]
# **13 -** Write a Python program to count the number of characters (character frequency) in a string

# %%
txt = input("Enter the String:")
char = input("Enter the Character to Count:")
val = txt.count(char)
print("Occurrence of Given Character is: ",val)

# %% [markdown]
# **14 -** What are negative indexes and why are they used?

# %% [markdown]
# **Ans -** The negative index is used to remove any new-line spaces from the string and allow the string to except
# the last character that is given as S[:-1].

# %% [markdown]
# **15 -** Write a Python program to count occurrences of a substring in a string.

# %%
string = input("Enter the String:")
sub_str = input("Enter the Character to Count:")
x = string.count(sub_str)
print("Occurrence of sub strig is: ",x)

# %% [markdown]
# **16 -** Write a Python program to count the occurrences of each word in a given sentence.

# %%
string = input("Enter string:")
word = input("Enter word:")
a=[]
count = 0
a=string.split(" ")
for i in range(0,len(a)):
      if(word==a[i]):
            count=count+1
print("Count of the word is:", count)

# %% [markdown]
# **17 -**  Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.

# %%
a = input("Enter First String : ")
b = input("Enter Second String : ")
x = a[0:2]
a = a .replace( a [0:2], b [0:2])
b = b.replace( b [0:2],  x )

print("Your first string is :- ", a )
print("Your second string is :- ", b )
print (a, " ",b)

# %% [markdown]
# **18 -**  Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing' then add 'ly' insteadif the string length of the given string is less than 3, leave it unchanged.

# %%
string = input("Enter the string :")
if len(string) < 3:
  print(string)
elif string[-3:] == 'ing':
  print(string + 'ly')
else:
  print(string + 'ing')

# %% [markdown]
# **19 -**  Write a Python program to find the first appearance of the substring 'not'and 'poor' froma given string, if 'not' follows the 'poor', replace the whole 'not'...'poor'substring with 'good'. Return the resulting string.

# %%
x = input("Enter a string :")
a = x.find('not')
b = x.find('poor')

if b > a and a > 0 and b > 0:
  x = x.replace(x[a:(b+4)],'good')
  print(x)
else:
  print(x)

# %% [markdown]
# **20 -**  Write a Python function that takes a list of words and returns the length of the longest one.

# %%
def find_longest_word(words_list):
    word_len = []
    for n in words_list:
        word_len.append((len(n), n))
    word_len.sort()
    return word_len[-1][0], word_len[-1][1]
result = find_longest_word(["PHP", "Exercises", "Backend"])
print("\nLongest word: ",result[1])
print("Length of the longest word: ",result[0])

# %% [markdown]
# **21 -**  Write a Python function to reverses a string if its length is a multiple of 4.

# %%
string=input("Enter a String:")

if( len(string) % 4==0):
  print(string[::-1])
else:
  print("cant")

# %% [markdown]
# **22 -**  Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. If the string length is lessthan 2 ,return instead of the empty string.
#
# *  Sample String:w3resource'
# *  Expected Result: 'w3ce'
# *  Sample String: 'w3'
# *  Expected Result: 'w3w3'
# *  Sample String: ' w'
# *  Expected Result: Empty String  List item

# %%
string = input("Enter a string :")

print("Result is :",string [0:2] + string [-2::] )

if len(string) < 2:
    print("Empty string ")
else:
    pass

# %% [markdown]
# **23 -** Write a Python function to insert a string in the middle of a string.

# %%
def str1(str, word):
	return str[:2] + word + str[2:]

print(str1('bean ', 'g'))
print(str1('weome', 'lc'))
print(str1('meor', 'nt'))
